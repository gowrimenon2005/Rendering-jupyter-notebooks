# %% [markdown]
# # Rendering jupyter notebooks
#
# This notebook had been made to test the functionalities of binder, voila and jupyter notebook. A bit of sample code and different forms of markdown will be presented to see how the final product looks.
#
# So this is a bit of random text that doesn't really have a purpose.
#
# Let's have a bit of python code!

# %%
# this is a basic python program that requires a user input 
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import *

def on_button_click(b):
    print("Button clicked.")
    given_value_ = given_value.value
    sns.set_style('whitegrid')
    plt.plot(given_value_, given_value_, 'ro')
    plt.xlabel('X axis')
    plt.ylabel('Y axis')
    plt.show()


given_value = widgets.Text(description='Enter value:')
display(given_value)

# print("The value you entered is: ", given_value)

# # lets plot this value on a graph
# sns.set_style('whitegrid')
# plt.plot(given_value, given_value, 'ro')
# plt.xlabel('X axis')
# plt.ylabel('Y axis')
# plt.show()

button = widgets.Button(description="Plot")
display(button)
button.on_click(on_button_click)
# Out:
# Text(value='', description='Enter value:')
# Button(description='Plot', style=ButtonStyle())
# Button clicked.

# %% [markdown]
# <span style='color:green'> Let's now have a bit of green text because it looks cool.

# %% [markdown]
# <div class="alert alert-block alert-success">
# No, wait lets have a green block of text because it looks more cool.
# <div>
#
# Yes this was cool but let's go back to python and see how to import functions from other files.

# %%
from function_file import *
from ipywidgets import *

rho_slider = FloatSlider(
    value=0.985,                    # Default value
    min=0.1,                        # Minimum value
    max=1.225,                      # Maximum value
    step=0.01,                      # Step size
    description='ρ: Air Density')

# Create an interactive plot
interact(something_with_widgets, rho=rho_slider)
# Out:
# interactive(children=(FloatSlider(value=0.985, description='ρ: Air Density', max=1.225, min=0.1, step=0.01), O…
# <function function_file.something_with_widgets(rho)>

# %% [markdown]
# ## Imagine a cool heading here
# Okay is this works so far that's already pretty good. The real test though is if it can now plot something based on user input. Let's try that out, shall we?

# %%
plot('sin')

# %% [markdown]
# Woohoo!! Hopefully everything worked so far! Because the last section was so much fun let's go back to it by clicking this hyperlink (which obviously will work, right?) [Revist the past](#imagine-a-cool-heading-here).
